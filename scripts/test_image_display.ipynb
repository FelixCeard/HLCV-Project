# %%
import torch
import matplotlib.pyplot as plt
import numpy

# %%
reconstructed = torch.load('./../reconstructed.pt')
reconstructed.shape
# Out:
# torch.Size([3, 3, 240, 360])

# %%
fig, ax = plt.subplots(1, 3, figsize=(3 * 5, 5))
for j in range(3):
    ax[j].imshow(reconstructed[j].permute(1, 2, 0).detach().cpu().clip(0, 1))
